# %%
import pandas as pd
import numpy as np

# %%
df_original = pd.read_excel('raw_data/SuEatableLife_Food_Fooprint_database.xlsx', sheet_name='SEL CF DATA SOURCES')

# %%
selected_columns = ['FOOD COMMODITY GROUP', 'FOOD COMMODITY TYPOLOGY', 'Carbon footprint  (kg CO2 eq/kg or litre of food commodity)', 'Country', 'Region']
df_emission = df_original[selected_columns]
df_emission.head()
# Out:
#      FOOD COMMODITY GROUP FOOD COMMODITY TYPOLOGY  \
# 0  AGRICULTURAL PROCESSED                    BEER
# 1  AGRICULTURAL PROCESSED                    BEER
# 2  AGRICULTURAL PROCESSED                    BEER
# 3  AGRICULTURAL PROCESSED                    BEER
# 4  AGRICULTURAL PROCESSED                    BEER
#
#    Carbon footprint  (kg CO2 eq/kg or litre of food commodity) Country  \
# 0                                             0.4200            Europe
# 1                                             0.5680             Italy
# 2                                             0.6660             Italy
# 3                                             0.8420                UK
# 4                                             0.9605             Italy
#
#                Region
# 0              Europe
# 1  Mediterranean area
# 2  Mediterranean area
# 3            N Europe
# 4  Mediterranean area

# %%
filtered_df = df_emission[df_emission['FOOD COMMODITY TYPOLOGY'] == 'BEER']
mean_emission = filtered_df['Carbon footprint  (kg CO2 eq/kg or litre of food commodity)'].mean()
mean_emission
# Out:
# 0.8141842105263157

# %%
mean_emission_sorted = (df_emission.groupby('FOOD COMMODITY TYPOLOGY')
                        .agg({'Carbon footprint  (kg CO2 eq/kg or litre of food commodity)': 'mean'}).reset_index()
                        .rename(columns={'Carbon footprint  (kg CO2 eq/kg or litre of food commodity)': 'Mean footprint (kg CO2 eq/kg or litre of commodity)'})
                        .sort_values(by='Mean footprint (kg CO2 eq/kg or litre of commodity)', ascending=False).reset_index(drop=True)
                        .round({'Mean footprint (kg CO2 eq/kg or litre of commodity)': 2})
                        )
mean_emission_sorted.head(50)
# Out:
#                FOOD COMMODITY TYPOLOGY  \
# 0               BUFFALO BONE FREE MEAT
# 1                  BEEF BONE FREE MEAT
# 2                  LAMB BONE FREE MEAT
# 3                  BEEF MEAT WITH BONE
# 4                  LAMB MEAT WITH BONE
# 5                     SHELLFISH FROZEN
# 6            HARD AND SEMI-HARD CHEESE
# 7                               BUTTER
# 8                            SHELLFISH
# 9                         FRUIT FROZEN
# 10           COFFEE GROUND & PARCHMENT
# 11                     PORK CURED MEAT
# 12                        FRESH CHEESE
# 13                 PORK BONE FREE MEAT
# 14                           ICE CREAM
# 15              POULTRY BONE FREE MEAT
# 16               RABBIT MEAT WITH BONE
# 17                                FISH
# 18             FRUIT HEATED GREENHOUSE
# 19         NUTS COVERED WITH CHOCOLATE
# 20                       KANGAROO MEAT
# 21                 PORK MEAT WITH BONE
# 22                         YEAST DRIED
# 23                                EGGS
# 24                                 OIL
# 25                           EGG PASTA
# 26              POULTRY MEAT WITH BONE
# 27                         FISH FROZEN
# 28        VEGETABLES HEATED GREENHOUSE
# 29                           CHOCOLATE
# 30  FRUIT JUICE (imported ingredients)
# 31                      EDIBLE INSECTS
# 32                               PESTO
# 33                   BREAKFAST CEREALS
# 34                                RICE
# 35                              YOGURT
# 36                   VEGETAL PROTEINS
# 37                      LEGUMES FROZEN
# 38                          NUTS PASTE
# 39                              SWEETS
# 40                      FISH PROCESSED
# 41                            MUSHROOM
# 42                               HONEY
# 43                       VEGETAL CREAM
# 44                            DRESSING
# 45                            BISCUITS
# 46                   VEGETABLES CANNED
# 47                                MILK
# 48                           MARGARINE
# 49         FRUIT GREENHOUSE NOT HEATED
#
#     Mean footprint (kg CO2 eq/kg or litre of commodity)
# 0                                               71.39
# 1                                               27.65
# 2                                               27.21
# 3                                               19.49
# 4                                               18.01
# 5                                               15.76
# 6                                               11.24
# 7                                                9.90
# 8                                                8.95
# 9                                                7.70
# 10                                               7.35
# 11                                               7.31
# 12                                               7.07
# 13                                               5.79
# 14                                               4.56
# 15                                               4.31
# 16                                               4.30
# 17                                               4.23
# 18                                               4.13
# 19                                               4.12
# 20                                               4.10
# 21                                               3.50
# 22                                               3.29
# 23                                               3.28
# 24                                               3.27
# 25                                               3.19
# 26                                               3.17
# 27                                               3.10
# 28                                               2.96
# 29                                               2.90
# 30                                               2.90
# 31                                               2.84
# 32                                               2.71
# 33                                               2.64
# 34                                               2.52
# 35                                               2.50
# 36                                               2.26
# 37                                               2.26
# 38                                               2.18
# 39                                               2.13
# 40                                               1.92
# 41                                               1.78
# 42                                               1.74
# 43                                               1.62
# 44                                               1.53
# 45                                               1.53
# 46                                               1.48
# 47                                               1.48
# 48                                               1.43
# 49                                               1.41

# %%
file_path = 'mean_emission_sorted.csv'
mean_emission_sorted.to_csv(file_path, index=False)
